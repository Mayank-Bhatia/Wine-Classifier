# %%
# %matplotlib inline
from IPython.display import HTML
import ipywidgets

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV, train_test_split

redwine = pd.read_csv('data/wine_quality_red.csv', sep=';')
whitewine = pd.read_csv('data/wine_quality_white.csv', sep=';')

# %%
from IPython.display import display
corr_rw = redwine.corr()

cmap = sns.diverging_palette(5, 250, as_cmap=True) # generate a colormap object

def magnify():
    # design "hover to magnify" features for the heatmap
    return [dict(selector="th",
                 props=[("font-size", "8.5pt")]),
            dict(selector="td",
                 props=[('padding', "0em 0em"), 
                        ("text-align", "center")]),
            dict(selector="th:hover",
                 props=[("font-size", "12pt")]),
            dict(selector="tr:hover td:hover",
                 props=[('max-width', '200px'),
                        ('font-size', '12pt')])
            ]

# generate heatmap
display(corr_rw.style.background_gradient(cmap, axis=1)\
    .set_properties(**{'max-width': '80px', 'font-size': '7pt'})\
    .set_caption("Hover to magify")\
    .set_precision(3)\
    .set_table_styles(magnify()))
# Out:
# <style  type="text/css" >
#     #T_e8b1973a_5fb2_11e7_b336_28d24417dce4 th {
#           font-size: 8.5pt;
#     }    #T_e8b1973a_5fb2_11e7_b336_28d24417dce4 td {
#           padding: 0em 0em;
#           text-align: center;
#     }    #T_e8b1973a_5fb2_11e7_b336_28d24417dce4 th:hover {
#           font-size: 12pt;
#     }    #T_e8b1973a_5fb2_11e7_b336_28d24417dce4 tr:hover td:hover {
#           max-width: 200px;
#           font-size: 12pt;
#     }    #T_e8b1973a_5fb2_11e7_b336_28d24417dce4row0_col0 {
#             background-color:  #4479bb;
#             max-width:  80px;
#             font-size:  7pt;
#         }    #T_e8b1973a_5fb2_11e7_b336_28d24417dce4row0_col1 {
#             background-color:  #ea97a8;
#             max-width:  80px;
#             font-size:  7pt;
#         }    #T_e8b1973a_5fb2_11e7_b336_28d24417dce4row0_col2 {
#             background-color:  #87a9d3;
#             max-width:  80px;
#             font-size:  7pt;
#         }    #T_e8b1973a_5fb2_11e7_b336_28d24417dce4row0_col3 {
#             background-color:  #fae8ec;
#             max-width:  80px;
#             font-size:  7pt;
#         }    #T_e8b1973a_5fb2_11e7_b336_28d24417dce4row0_col4 {
#             background-color:  #fae4e9;
#             max-width:  80px;
#             font-size:  7pt;
#         }    #T_e8b1973a_5fb2_11e7_b336_28d24417dce4row0_col5 {
#             background-color:  #eeaebb;
#             max-width:  80px;
#             font-size:  7pt;
#         }    #T_e8b1973a_5fb2_11e7_b336_28d24417dce4row0_col6 {
#             background-color:  #f0b7c2;
#             max-width:  80px;
#             font-size:  7pt;
#         }    #T_e8b1973a_5fb2_11e7_b336_28d24417dce4row0_col7 {
#             background-color:  #89aad4;
#             max-width:  80px;
#             font-size:  7pt;
#         }    #T_e8b1973a_5fb2_11e7_b336_28d24417dce4row0_col8 {
#             background-color:  #d73c5b;
#             max-width:  80px;
#             font-size:  7pt;
#         }    #T_e8b1973a_5fb2_11e7_b336_28d24417dce4row0_col9 {
#             background-color:  #f2f2f2;
#             max-width:  80px;
#             font-size:  7pt;
#         }    #T_e8b1973a_5fb2_11e7_b336_28d24417dce4row0_col10 {
#             background-color:  #f3c2cc;
#             max-width:  80px;
#             font-size:  7pt;
#         }    #T_e8b1973a_5fb2_11e7_b336_28d24417dce4row0_col11 {
#             background-color:  #fbeaed;
#             max-width:  80px;
#             font-size:  7pt;
#         }    #T_e8b1973a_5fb2_11e7_b336_28d24417dce4row1_col0 {
#             background-color:  #e58094;
#             max-width:  80px;
#             font-size:  7pt;
#         }    #T_e8b1973a_5fb2_11e7_b336_28d24417dce4row1_col1 {
#             background-color:  #4479bb;
#             max-width:  80px;
#             font-size:  7pt;
#         }    #T_e8b1973a_5fb2_11e7_b336_28d24417dce4row1_col2 {
#             background-color:  #d73c5b;
#             max-width:  80px;
#             font-size:  7pt;
#         }    #T_e8b1973a_5fb2_11e7_b336_28d24417dce4row1_col3 {
#             background-color:  #f2bdc8;
#             max-width:  80px;
#             font-size:  7pt;
#         }    #T_e8b1973a_5fb2_11e7_b336_28d24417dce4row1_col4 {
#             background-color:  #f5ccd4;
#             max-width:  80px;
#             font-size:  7pt;
#         }    #T_e8b1973a_5fb2_11e7_b336_28d24417dce4row1_col5 {
#             background-color:  #f1bbc6;
#             max-width:  80px;
#             font-size:  7pt;
#         }    #T_e8b1973a_5fb2_11e7_b336_28d24417dce4row1_col6 {
#             background-color:  #f5cfd7;
#             max-width:  80px;
#             font-size:  7pt;
#         }    #T_e8b1973a_5fb2_11e7_b336_28d24417dce4row1_col7 {
#             background-color:  #f3c2cc;
#             max-width:  80px;
#             font-size:  7pt;
#         }    #T_e8b1973a_5fb2_11e7_b336_28d24417dce4row1_col8 {
#             background-color:  #f2f2f2;
#             max-width:  80px;
#             font-size:  7pt;
#         }    #T_e8b1973a_5fb2_11e7_b336_28d24417dce4row1_col9 {
#             background-color:  #e58094;
#             max-width:  80px;
#             font-size:  7pt;
#         }    #T_e8b1973a_5fb2_11e7_b336_28d24417dce4row1_col10 {
#             background-color:  #e88d9f;
#             max-width:  80px;
#             font-size:  7pt;
#         }    #T_e8b1973a_5fb2_11e7_b336_28d24417dce4row1_col11 {
#             background-color:  #df617a;
#             max-width:  80px;
#             font-size:  7pt;
#         }    #T_e8b1973a_5fb2_11e7_b336_28d24417dce4row2_col0 {
#             background-color:  #8faed6;
#             max-width:  80px;
#             font-size:  7pt;
#         }    #T_e8b1973a_5fb2_11e7_b336_28d24417dce4row2_col1 {
#             background-color:  #d73c5b;
#             max-width:  80px;
#             font-size:  7pt;
#         }    #T_e8b1973a_5fb2_11e7_b336_28d24417dce4row2_col2 {
#             background-color:  #4479bb;
#             max-width:  80px;
#             font-size:  7pt;
#         }    #T_e8b1973a_5fb2_11e7_b336_28d24417dce4row2_col3 {
#             background-color:  #f8dfe4;
#             max-width:  80px;
#             font-size:  7pt;
#         }    #T_e8b1973a_5fb2_11e7_b336_28d24417dce4row2_col4 {
#             background-color:  #f2f2f2;
#             max-width:  80px;
#             font-size:  7pt;
#         }    #T_e8b1973a_5fb2_11e7_b336_28d24417dce4row2_col5 {
#             background-color:  #efafbc;
#             max-width:  80px;
#             font-size:  7pt;
#         }    #T_e8b1973a_5fb2_11e7_b336_28d24417dce4row2_col6 {
#             background-color:  #f3c5ce;
#             max-width:  80px;
#             font-size:  7pt;
#         }    #T_e8b1973a_5fb2_11e7_b336_28d24417dce4row2_col7 {
#             background-color:  #d4e0ef;
#             max-width:  80px;
#             font-size:  7pt;
#         }    #T_e8b1973a_5fb2_11e7_b336_28d24417dce4row2_col8 {
#             background-color:  #d73d5c;
#             max-width:  80px;
#             font-size:  7pt;
#         }    #T_e8b1973a_5fb2_11e7_b336_28d24417dce4row2_col9 {
#             background-color:  #e0e9f4;
#             max-width:  80px;
#             font-size:  7pt;
#         }    #T_e8b1973a_5fb2_11e7_b336_28d24417dce4row2_col10 {
#             background-color:  #f7d7de;
#             max-width:  80px;
#             font-size:  7pt;
#         }    #T_e8b1973a_5fb2_11e7_b336_28d24417dce4row2_col11 {
#             background-color:  #f2f2f2;
#             max-width:  80px;
#             font-size:  7pt;
#         }    #T_e8b1973a_5fb2_11e7_b336_28d24417dce4row3_col0 {
#             background-color:  #e57f93;
#             max-width:  80px;
#             font-size:  7pt;
#         }    #T_e8b1973a_5fb2_11e7_b336_28d24417dce4row3_col1 {
#             background-color:  #dd5872;
#             max-width:  80px;
#             font-size:  7pt;
#         }    #T_e8b1973a_5fb2_11e7_b336_28d24417dce4row3_col2 {
#             background-color:  #e7899c;
#             max-width:  80px;
#             font-size:  7pt;
#         }    #T_e8b1973a_5fb2_11e7_b336_28d24417dce4row3_col3 {
#             background-color:  #4479bb;
#             max-width:  80px;
#             font-size:  7pt;
#         }    #T_e8b1973a_5fb2_11e7_b336_28d24417dce4row3_col4 {
#             background-color:  #e16b82;
#             max-width:  80px;
#             font-size:  7pt;
#         }    #T_e8b1973a_5fb2_11e7_b336_28d24417dce4row3_col5 {
#             background-color:  #ea97a8;
#             max-width:  80px;
#             font-size:  7pt;
#         }    #T_e8b1973a_5fb2_11e7_b336_28d24417dce4row3_col6 {
#             background-color:  #eb9dac;
#             max-width:  80px;
#             font-size:  7pt;
#         }    #T_e8b1973a_5fb2_11e7_b336_28d24417dce4row3_col7 {
#             background-color:  #f5cfd7;
#             max-width:  80px;
#             font-size:  7pt;
#         }    #T_e8b1973a_5fb2_11e7_b336_28d24417dce4row3_col8 {
#             background-color:  #d73c5b;
#             max-width:  80px;
#             font-size:  7pt;
#         }    #T_e8b1973a_5fb2_11e7_b336_28d24417dce4row3_col9 {
#             background-color:  #dd5a74;
#             max-width:  80px;
#             font-size:  7pt;
#         }    #T_e8b1973a_5fb2_11e7_b336_28d24417dce4row3_col10 {
